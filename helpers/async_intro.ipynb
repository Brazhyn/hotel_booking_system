# %%
import time
import asyncio

# %%
def get_data_from_database(query: str):
    print(f"Отримано запит: {query}")
    if query == "Сочи":
        time.sleep(4)
    elif query == "Дубай":
        time.sleep(2)
    print(f"Дані отримано: {query}")

# %%
get_data_from_database("Сочи")
get_data_from_database("Дубай")
# Out:
# Отримано запит: Сочи
# Дані отримано: Сочи
# Отримано запит: Дубай
# Дані отримано: Дубай

# %%
async def get_data_from_database_async(query: str):
    print(f"Отримано запит: {query}")
    if query == "Сочи":
        await asyncio.sleep(4)
    elif query == "Дубай":
        await asyncio.sleep(2)
    print(f"Дані отримано: {query}")

# %%
await get_data_from_database_async("Сочи")
await get_data_from_database_async("Дубай")
# Out:
# Отримано запит: Сочи
# Дані отримано: Сочи
# Отримано запит: Дубай
# Дані отримано: Дубай
